# %%
import pandas as pd

# %%
cancer_hotspot=pd.read_excel('/Users/hatice.irmak/Desktop/somatic_rules/hotspots_v2.xls')

# %%
pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 576.6 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
cancer_hotspot.columns
# Out:
# Index(['Hugo_Symbol', 'Amino_Acid_Position', 'log10_pvalue', 'Mutation_Count',
#        'Reference_Amino_Acid', 'Total_Mutations_in_Gene',
#        'Median_Allele_Freq_Rank', 'Allele_Freq_Rank', 'Variant_Amino_Acid',
#        'Codon_Change', 'Genomic_Position', 'Detailed_Cancer_Types',
#        'Organ_Types', 'Tri-nucleotides', 'Mutability', 'mu_protein',
#        'Total_Samples', 'Analysis_Type', 'qvalue', 'tm', 'qvalue_pancan',
#        'Is_repeat', 'seq', 'length', 'align100', 'pad12entropy',
#        'pad24entropy', 'pad36entropy', 'TP', 'reason', 'n_MSK', 'n_Retro',
#        'judgement', 'inNBT', 'inOncokb', 'ref', 'qvaluect', 'ct', 'Samples'],
#       dtype='object')

# %%
cancer_hotspot.head(10)
# Out:
#   Hugo_Symbol Amino_Acid_Position  log10_pvalue  Mutation_Count  \
# 0        NRAS                  61  -1237.691435             422
# 1        NRAS                  61  -1237.691435             422
# 2        NRAS                  61  -1237.691435             422
# 3        NRAS                  61  -1237.691435             422
# 4        NRAS                  61  -1237.691435             422
# 5        NRAS                  61  -1237.691435             422
# 6      PIK3CA                 545  -1368.829746             633
# 7      PIK3CA                 545  -1368.829746             633
# 8      PIK3CA                 545  -1368.829746             633
# 9      PIK3CA                 545  -1368.829746             633
#
#   Reference_Amino_Acid  Total_Mutations_in_Gene  Median_Allele_Freq_Rank  \
# 0                Q:422                      620                 0.333333
# 1                Q:422                      620                 0.333333
# ...

# %%
cancer_hotspot_revised = cancer_hotspot[['Hugo_Symbol', 'Amino_Acid_Position', 'Mutation_Count',
       'Reference_Amino_Acid', 'Total_Mutations_in_Gene',
    'Variant_Amino_Acid',
       'Codon_Change', 'Genomic_Position', 'Detailed_Cancer_Types',
       'Organ_Types', 'ref', 'ct', 'Samples']]

# %%
cancer_hotspot_revised
# Out:
#      Hugo_Symbol Amino_Acid_Position  Mutation_Count Reference_Amino_Acid  \
# 0           NRAS                  61             422                Q:422
# 1           NRAS                  61             422                Q:422
# 2           NRAS                  61             422                Q:422
# 3           NRAS                  61             422                Q:422
# 4           NRAS                  61             422                Q:422
# ...          ...                 ...             ...                  ...
# 2999       FBXW7                 385               4                  T:4
# 3000       FBXW7                 385               4                  T:4
# 3001       FBXW7                 385               4                  T:4
# 3002       FBXW7                 393               7                  R:7
# 3003       FBXW7                 393               7                  R:7
#
#       Total_Mutations_in_Gene Variant_Amino_Acid  \
# ...

# %%
cancer_hotspot_revised['id'] = cancer_hotspot_revised.apply(lambda x: x['Hugo_Symbol']+'_'+x['ref']+x['Amino_Acid_Position']+x['Variant_Amino_Acid'].split(':')[0], axis=1)
# Out:
# /var/folders/b5/l8j1n8w540z4sdqxmw14qv380000gn/T/ipykernel_46501/1778280447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cancer_hotspot_revised['id'] = cancer_hotspot_revised.apply(lambda x: x['Hugo_Symbol']+'_'+x['ref']+x['Amino_Acid_Position']+x['Variant_Amino_Acid'].split(':')[0], axis=1)

# %%
cancer_hotspot_revised
# Out:
#      Hugo_Symbol Amino_Acid_Position  Mutation_Count Reference_Amino_Acid  \
# 0           NRAS                  61             422                Q:422
# 1           NRAS                  61             422                Q:422
# 2           NRAS                  61             422                Q:422
# 3           NRAS                  61             422                Q:422
# 4           NRAS                  61             422                Q:422
# ...          ...                 ...             ...                  ...
# 2999       FBXW7                 385               4                  T:4
# 3000       FBXW7                 385               4                  T:4
# 3001       FBXW7                 385               4                  T:4
# 3002       FBXW7                 393               7                  R:7
# 3003       FBXW7                 393               7                  R:7
#
#       Total_Mutations_in_Gene Variant_Amino_Acid  \
# ...

# %%
import re



samplecount = 'skin:88|thyroid:54|blood:15|bowel:8|testis:5|biliarytract:4|bladder:4|lung:4|ovaryfallopiantube:4|softtissue:3|unk:3|uterus:3|cnsbrain:2|esophagusstomach:2|headandneck:2|bone:1|pancreas:1|thymus:1'
numbers = re.findall(r'\d+',samplecount)
numbers_int = [int(x) for x in numbers]
sum(numbers_int)
# Out:
# 204

# %%
cancer_hotspot_revised['total_variant_count'] = cancer_hotspot_revised['Variant_Amino_Acid'].apply(lambda x: x.split(':')[-1])
# Out:
# /var/folders/b5/l8j1n8w540z4sdqxmw14qv380000gn/T/ipykernel_46501/2899986092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cancer_hotspot_revised['total_variant_count'] = cancer_hotspot_revised['Variant_Amino_Acid'].apply(lambda x: x.split(':')[-1])

# %%
cancer_hotspot_revised
# Out:
#      Hugo_Symbol Amino_Acid_Position  Mutation_Count Reference_Amino_Acid  \
# 0           NRAS                  61             422                Q:422
# 1           NRAS                  61             422                Q:422
# 2           NRAS                  61             422                Q:422
# 3           NRAS                  61             422                Q:422
# 4           NRAS                  61             422                Q:422
# ...          ...                 ...             ...                  ...
# 2999       FBXW7                 385               4                  T:4
# 3000       FBXW7                 385               4                  T:4
# 3001       FBXW7                 385               4                  T:4
# 3002       FBXW7                 393               7                  R:7
# 3003       FBXW7                 393               7                  R:7
#
#       Total_Mutations_in_Gene Variant_Amino_Acid  \
# ...

# %%
cancer_hotspot_revised.to_csv('cancer_hotspots_revised.csv')
